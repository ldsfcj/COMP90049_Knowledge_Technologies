# %%
import textdistance
candidatefile = open(r"C:\Users\JCCH4\Downloads\2019S2-COMP90049_proj1-data_windows\2019S2-COMP90049_proj1-data_windows\candidates.txt")
dictionalfile = open(r"C:\Users\JCCH4\Downloads\2019S2-COMP90049_proj1-data_windows\2019S2-COMP90049_proj1-data_windows\dict.txt")
blendsfile = open(r"C:\Users\JCCH4\Downloads\2019S2-COMP90049_proj1-data_windows\2019S2-COMP90049_proj1-data_windows\blends.txt")
blendwords1 = [[d1.split()[0],d1.split()[1],d1.split()[2]] for d1 in blendsfile]
candidatewords = [d.split()[0] for d in candidatefile]
dictionalwords = [dic.split()[0] for dic in dictionalfile]
average1 = 0
average2 = 0
total1 = 0
total2 = 0
for word in blendwords:
    total1 += textdistance.jaro_winkler(word[0],word[1])
    total2 += textdistance.jaro_winkler(word[0],word[2])
    print(word[0],word[1],textdistance.jaro_winkler(word[0],word[1]),word[0],word[2],textdistance.jaro_winkler(word[0],word[2]))
print(total1/len(blendwords),total2/len(blendwords))
# Out:
# aaah aaa 0.9166666666666666 aaah 0.9166666666666666 0.0
# aahh aah 0.9166666666666666 aahh 0.9166666666666666 0.0
# aahora anaphora 0.9249999999999999 aahora 0.9249999999999999 0.0
# aaliyah aliya 0.9142857142857143 aaliyah 0.9142857142857143 0.0
# abangnya abanga 0.95 abangnya 0.95 0.0
# abbrieviate abbrev 0.9090909090909091 abbrieviate 0.9090909090909091 0.0
# abdc abc 0.9166666666666666 abdc 0.9166666666666666 0.0
# abeg abe 0.9166666666666666 abeg 0.9166666666666666 0.0
# abegg abegge 0.9666666666666667 abegg 0.9666666666666667 0.0
# abeto abet 0.96 abeto 0.96 0.0
# abi abib 0.9166666666666666 abi 0.9166666666666666 0.0
# abierto abie 0.9142857142857143 abierto 0.9142857142857143 0.0
# abis abaris 0.9111111111111111 abis 0.9111111111111111 0.0
# abisan abasing 0.9174603174603175 abisan 0.9174603174603175 0.0
# abita abatic 0.9022222222222223 abita 0.9022222222222223 0.0
# ablum album 0.94 ablum 0.94 0.0
# aboarding aboard 0.9333333333333333 aboarding 0.9333333333333333 0.0
# ...

# %%
# def FindCommPrefix(w1,w2):
#     i = 0
#     while(i<min(len(w1),len(w2))):
#         if(w1[i]==w2[i]):
#             i+=1
#         else:
#             break
#     return w1[:i]

# def Find_Match_JaroWinkler(can,dictionalwords):
#     similarity = 0.9
#     dicword = ''
#     for dic in dictionalwords:
#         jarnum = textdistance.jaro_winkler(can,dic)
#         if(jarnum > similarity):
#             similarity = jarnum
#             dicword = dic
#             print(dicword, similarity)
#             break
#     return dicword

# # print(Find_Match_JaroWinkler('aaaaa',dictionalwords))
# for w in candidatewords:
#     best_pre = Find_Match_JaroWinkler(w,dictionalwords)

# %%
# for word in blendwords:
#     i=0
#     print(word[0],word[1])
#     while (i < min(len(word[0]),len(word[1]))):
#         if (word[0][i]==word[1][i]):
#             prin(word[0][i])
#             i+=
#         else:
#             break
#     print(i)

# def FindBestMatch_JaroWinkler(can):
#     similarity = 0
#     dicword = ''
#     for dic in dictionalwords:
#         jarnum = textdistance.jaro_winkler(can,dic)
#         if(jarnum > similarity):
#             similarity = jarnum
#             dicword = dic
#     print(dicword, similarity)
#     return dicword
# Out:
# aa

# %%
a = [i for i in dictionalwords if i[0]=='a']
b = [i for i in dictionalwords if i[0]=='b']
c = [i for i in dictionalwords if i[0]=='c']
d = [i for i in dictionalwords if i[0]=='d']
e = [i for i in dictionalwords if i[0]=='e']
f = [i for i in dictionalwords if i[0]=='f']
g = [i for i in dictionalwords if i[0]=='g']
h = [i for i in dictionalwords if i[0]=='h']
i = [i for i in dictionalwords if i[0]=='i']
j = [i for i in dictionalwords if i[0]=='j']
k = [i for i in dictionalwords if i[0]=='k']
l = [i for i in dictionalwords if i[0]=='l']
m = [i for i in dictionalwords if i[0]=='m']
n = [i for i in dictionalwords if i[0]=='n']
o = [i for i in dictionalwords if i[0]=='o']
p = [i for i in dictionalwords if i[0]=='p']
q = [i for i in dictionalwords if i[0]=='q']
r = [i for i in dictionalwords if i[0]=='r']
s = [i for i in dictionalwords if i[0]=='s']
t = [i for i in dictionalwords if i[0]=='t']
u = [i for i in dictionalwords if i[0]=='u']
v = [i for i in dictionalwords if i[0]=='v']
w = [i for i in dictionalwords if i[0]=='w']
x = [i for i in dictionalwords if i[0]=='x']
y = [i for i in dictionalwords if i[0]=='y']
z = [i for i in dictionalwords if i[0]=='z']

# %%
# Out:
# ['i',
#  'ia',
#  'iacchic',
#  'iacchos',
#  'iacchus',
#  'iachimo',
#  'iago',
#  'iamatology',
#  'iamb',
#  'iambe',
#  'iambelegus',
#  'iambi',
#  'iambic',
#  'iambical',
#  'iambically',
#  'iambics',
#  'iambist',
#  'iambize',
#  'iambographer',
#  'iambs',
#  'iambus',
#  'iambuses',
#  'ian',
#  'ianthina',
#  'ianthine',
#  'ianthinite',
#  'ianus',
#  'iao',
#  'iapetus',
#  'iapyges',
#  'iapygian',
#  'iapygii',
#  'iare',
#  'iarovization',
#  'iarovize',
#  'iarovized',
#  'iarovizing',
#  'iatraliptic',
#  'iatraliptics',
#  'iatric',
#  'iatrical',
#  'iatrochemic',
#  'iatrochemical',
#  'iatrochemically',
#  'iatrochemist',
#  'iatrochemistry',
#  'iatrogenic',
#  'iatrogenically',
#  'iatrogenicity',
#  'iatrological',
#  'iatrology',
#  'iatromathematical',
#  'iatromathematician',
#  'iatromathematics',
#  'iatromechanical',
#  'iatromechanist',
#  'iatrophysical',
#  'iatrophysicist',
#  'iatrophysics',
#  'iatrotechnics',
#  'ib',
#  'iba',
#  'ibad',
# ...

# %%
def FindCommPrefix(w1,w2):
    i = 0
    while(i<min(len(w1),len(w2))):
        if(w1[i]==w2[i]):
            i+=1
        else:
            break
    return w1[:i],w1[i:]

def Find_Match_JaroWinkler(can,dictionalwords):
    similarity = 0.9
    dicword = ''
    for dic in dictionalwords:
        jarnum = textdistance.jaro_winkler(can,dic)
        if(jarnum > similarity):
            similarity = jarnum
            dicword = dic
            print(can,dicword, similarity)
            break
    return dicword
# 
# print(Find_Match_JaroWinkler('aaaaa',dictionalwords))
for word in candidatewords:
#     if(word[0]=='a'):
#         best_pre = Find_Match_JaroWinkler(word,a)
#     elif(word[0]=='b'):
#         best_pre = Find_Match_JaroWinkler(word,b)
#     elif(word[0]=='c'):
#         best_pre = Find_Match_JaroWinkler(word,c)
#     elif(word[0]=='d'):
#         best_pre = Find_Match_JaroWinkler(word,d)
#     elif(word[0]=='e'):
#         best_pre = Find_Match_JaroWinkler(word,e)
#     elif(word[0]=='f'):
#         best_pre = Find_Match_JaroWinkler(word,f)
#     elif(word[0]=='g'):
#         best_pre = Find_Match_JaroWinkler(word,g)
#     elif(word[0]=='h'):
#         best_pre = Find_Match_JaroWinkler(word,h)
#     elif(word[0]=='i'):
#         best_pre = Find_Match_JaroWinkler(word,i)
#     elif(word[0]=='j'):
#         best_pre = Find_Match_JaroWinkler(word,j)
#     elif(word[0]=='k'):
#         best_pre = Find_Match_JaroWinkler(word,k)
#     elif(word[0]=='l'):
#         best_pre = Find_Match_JaroWinkler(word,l)
#     elif(word[0]=='m'):
#         best_pre = Find_Match_JaroWinkler(word,m)
#     elif(word[0]=='n'):
#         best_pre = Find_Match_JaroWinkler(word,n)
#     elif(word[0]=='o'):
#         best_pre = Find_Match_JaroWinkler(word,o)
#     elif(word[0]=='p'):
#         best_pre = Find_Match_JaroWinkler(word,p)
#     elif(word[0]=='q'):
#         best_pre = Find_Match_JaroWinkler(word,q)
#     elif(word[0]=='i'):
#         best_pre = Find_Match_JaroWinkler(word,i)
#     elif(word[0]=='s'):
#         best_pre = Find_Match_JaroWinkler(word,s)
#     elif(word[0]=='t'):
#         best_pre = Find_Match_JaroWinkler(word,t)
#     elif(word[0]=='u'):
#         best_pre = Find_Match_JaroWinkler(word,u)
#     elif(word[0]=='v'):
#         best_pre = Find_Match_JaroWinkler(word,v)
#     elif(word[0]=='w'):
#         best_pre = Find_Match_JaroWinkler(word,w)
#     elif(word[0]=='x'):
#         best_pre = Find_Match_JaroWinkler(word,x)
#     elif(word[0]=='y'):
#         best_pre = Find_Match_JaroWinkler(word,y)
#     elif(word[0]=='z'):
#         best_pre = Find_Match_JaroWinkler(word,z)
    if(word[0]=='r'):
        best_pre = Find_Match_JaroWinkler(word,r)
# Out:
# raas raasch 0.9333333333333333
# rabit rabat 0.9066666666666667
# raburn raun 0.9111111111111111
# rac race 0.9166666666666666
# raccon raccoon 0.9714285714285714
# racha rach 0.96
# rachelle rache 0.925
# racis racemism 0.9125
# racistas racialists 0.9225
# racun racon 0.9066666666666667
# radda rada 0.9533333333333333
# radley raddle 0.9222222222222223
# rae race 0.9166666666666666
# raean ramean 0.9555555555555556
# rafikki rafik 0.9428571428571428
# ragedy rage 0.9333333333333333
# ragga raga 0.9533333333333333
# raggady ragged 0.9095238095238095
# rahm rah 0.9166666666666666
# rainboots rainbow 0.9047619047619048
# rainbowed rainbound 0.9111111111111111
# raindance radiance 0.9037037037037037
# rainin rain 0.9333333333333333
# rajon rajoguna 0.925
# rakillosa rakis 0.9111111111111111
# rakim raki 0.96
# raleigh rale 0.9142857142857143
# ralphie ralph 0.9428571428571428
# ramatu rama 0.9333333333333333
# ramen ragmen 0.9555555555555556
# ramirez rami 0.9142857142857143
# ...

# %%
def FindCommPrefix(w1,w2):
    i = 0
    while(i<min(len(w1),len(w2))):
        if(w1[i]==w2[i]):
            i+=1
        else:
            break
    return w1[:i],w1[i:]
jaro_prefix = open(r"C:\Users\JCCH4\Downloads\Jrao_winkler_predict_prefix.txt")
blendwords = [[d1.split()[0],d1.split()[1],d1.split()[2]] for d1 in jaro_prefix]
count = 0
for i in blendwords:
    count+=1
    print(i[0],i[1],FindCommPrefix(i[0],i[1]))
    g = FindCommPrefix(i[0],i[1])
    print(g[1][::-1])
#     print(i[1],i[2])
print(count)
# Out:
# aaah aaa ('aaa', 'h')
# h
# aahh aah ('aah', 'h')
# h
# aahora anaphora ('a', 'ahora')
# aroha
# aaliyah aliya ('a', 'aliyah')
# hayila
# abangnya abanga ('abang', 'nya')
# ayn
# abbrieviate abbrev ('abbr', 'ieviate')
# etaivei
# abdc abc ('ab', 'dc')
# cd
# abeg abe ('abe', 'g')
# g
# abegg abegge ('abegg', '')
#
# abeto abet ('abet', 'o')
# o
# abi abib ('abi', '')
#
# abierto abie ('abie', 'rto')
# otr
# abis abaris ('ab', 'is')
# si
# abisan abasing ('ab', 'isan')
# nasi
# abita abatic ('ab', 'ita')
# ati
# ablum album ('a', 'blum')
# mulb
# aboarding aboard ('aboard', 'ing')
# gni
# abonmination abannition ('ab', 'onmination')
# noitanimno
# abot abacot ('ab', 'ot')
# to
# abots abbots ('ab', 'ots')
# sto
# abou abo ('abo', 'u')
# u
# abouta abought ('abou', 'ta')
# at
# aboutn abought ('abou', 'tn')
# nt
# aboutt abbott ('ab', 'outt')
# ttuo
# aboutta about ('about', 'ta')
# at
# abouttt about ('about', 'tt')
# tt
# abouttta about ('about', 'tta')
# att
# ...

# %%
r_a = [d[::-1] for d in dictionalwords if d[-1]=='a']
r_b = [d[::-1] for d in dictionalwords if d[-1]=='b']
r_c = [d[::-1] for d in dictionalwords if d[-1]=='c']
r_d = [d[::-1] for d in dictionalwords if d[-1]=='d']
r_e = [d[::-1] for d in dictionalwords if d[-1]=='e']
r_f = [d[::-1] for d in dictionalwords if d[-1]=='f']
r_g = [d[::-1] for d in dictionalwords if d[-1]=='g']
r_h = [d[::-1] for d in dictionalwords if d[-1]=='h']
r_i = [d[::-1] for d in dictionalwords if d[-1]=='i']
r_j = [d[::-1] for d in dictionalwords if d[-1]=='j']
r_k = [d[::-1] for d in dictionalwords if d[-1]=='k']
r_l = [d[::-1] for d in dictionalwords if d[-1]=='l']
r_m = [d[::-1] for d in dictionalwords if d[-1]=='m']
r_n = [d[::-1] for d in dictionalwords if d[-1]=='n']
r_o = [d[::-1] for d in dictionalwords if d[-1]=='o']
r_p = [d[::-1] for d in dictionalwords if d[-1]=='p']
r_q = [d[::-1] for d in dictionalwords if d[-1]=='q']
r_r = [d[::-1] for d in dictionalwords if d[-1]=='r']
r_s = [d[::-1] for d in dictionalwords if d[-1]=='s']
r_t = [d[::-1] for d in dictionalwords if d[-1]=='t']
r_u = [d[::-1] for d in dictionalwords if d[-1]=='u']
r_v = [d[::-1] for d in dictionalwords if d[-1]=='v']
r_w = [d[::-1] for d in dictionalwords if d[-1]=='w']
r_x = [d[::-1] for d in dictionalwords if d[-1]=='x']
r_y = [d[::-1] for d in dictionalwords if d[-1]=='y']
r_z = [d[::-1] for d in dictionalwords if d[-1]=='z']

# %%
count1 = 0
for i in blendwords:
    count1+=1
    print(count1,i[0],i[1],FindCommPrefix(i[0],i[1])[1][::-1])
# Out:
# 1 aaah aaa h
# 2 aahh aah h
# 3 aahora anaphora aroha
# 4 aaliyah aliya hayila
# 5 abangnya abanga ayn
# 6 abbrieviate abbrev etaivei
# 7 abdc abc cd
# 8 abeg abe g
# 9 abegg abegge
# 10 abeto abet o
# 11 abi abib
# 12 abierto abie otr
# 13 abis abaris si
# 14 abisan abasing nasi
# 15 abita abatic ati
# 16 ablum album mulb
# 17 aboarding aboard gni
# 18 abonmination abannition noitanimno
# 19 abot abacot to
# 20 abots abbots sto
# 21 abou abo u
# 22 abouta abought at
# 23 aboutn abought nt
# 24 aboutt abbott ttuo
# 25 aboutta about at
# 26 abouttt about tt
# 27 abouttta about att
# 28 aboyt abody ty
# 29 abput abrupt tup
# 30 abreee abreed e
# 31 abril abri l
# 32 absoultely absolute yletlu
# 33 absouluetly absolent ylteulu
# 34 abtt abattu tt
# 35 abuela abel aleu
# 36 abuelo abel oleu
# 37 aca acad
# 38 acaban acana nab
# 39 acabar acamar rab
# 40 acabe acale eb
# 41 acay acracy ya
# 42 accento acce otn
# 43 accidenty accent ytnedi
# 44 accoutable accable elbatuo
# ...

# %%
ReSufJW = open(r"C:\Users\JCCH4\Downloads\Re_Suffix_Jaro_Winkler.txt")
ReSufJWwords = [[line.split()[0],line.split()[1],line.split()[3]] for line in ReSufJW if len(line.split())>3]
count2 = 0
for i in ReSufJWwords:
    if(i[2][0]=='a'):
        best_pre = Find_Match_JaroWinkler(i[2],r_a)
        if(best_pre):
            count2+=1
            print(count2,i[1])
    elif(i[2][0]=='b'):
        best_pre = Find_Match_JaroWinkler(i[2],r_b)
        if(best_pre):
            count2+=1
            print(count2,i[1])
    elif(i[2][0]=='c'):
        best_pre = Find_Match_JaroWinkler(i[2],r_c)
        if(best_pre):
            count2+=1
            print(count2,i[1])
    elif(i[2][0]=='d'):
        best_pre = Find_Match_JaroWinkler(i[2],r_d)
        if(best_pre):
            count2+=1
            print(count2,i[1])
    elif(i[2][0]=='e'):
        best_pre = Find_Match_JaroWinkler(i[2],r_e)
        if(best_pre):
            count2+=1
            print(count2,i[1])
    elif(i[2][0]=='f'):
        best_pre = Find_Match_JaroWinkler(i[2],r_f)
        if(best_pre):
            count2+=1
            print(count2,i[1])
    elif(i[2][0]=='g'):
        best_pre = Find_Match_JaroWinkler(i[2],r_g)
        if(best_pre):
            count2+=1
            print(count2,i[1])
    elif(i[2][0]=='h'):
        best_pre = Find_Match_JaroWinkler(i[2],r_h)
        if(best_pre):
            count2+=1
            print(count2,i[1])
    elif(i[2][0]=='i'):
        best_pre = Find_Match_JaroWinkler(i[2],r_i)
        if(best_pre):
            count2+=1
            print(count2,i[1])
    elif(i[2][0]=='j'):
        best_pre = Find_Match_JaroWinkler(i[2],r_j)
        if(best_pre):
            count2+=1
            print(count2,i[1])
    elif(i[2][0]=='k'):
        best_pre = Find_Match_JaroWinkler(i[2],r_k)
        if(best_pre):
            count2+=1
            print(count2,i[1])
    elif(i[2][0]=='l'):
        best_pre = Find_Match_JaroWinkler(i[2],r_l)
        if(best_pre):
            count2+=1
            print(count2,i[1])
    elif(i[2][0]=='m'):
        best_pre = Find_Match_JaroWinkler(i[2],r_m)
        if(best_pre):
            count2+=1
            print(count2,i[1])
    elif(i[2][0]=='n'):
        best_pre = Find_Match_JaroWinkler(i[2],r_n)
        if(best_pre):
            count2+=1
            print(count2,i[1])
    elif(i[2][0]=='o'):
        best_pre = Find_Match_JaroWinkler(i[2],r_o)
        if(best_pre):
            count2+=1
            print(count2,i[1])
    elif(i[2][0]=='p'):
        best_pre = Find_Match_JaroWinkler(i[2],r_p)
        if(best_pre):
            count2+=1
            print(count2,i[1])
    elif(i[2][0]=='q'):
        best_pre = Find_Match_JaroWinkler(i[2],r_q)
        if(best_pre):
            count2+=1
            print(count2,i[1])
    elif(i[2][0]=='r'):
        best_pre = Find_Match_JaroWinkler(i[2],r_r)
        if(best_pre):
            count2+=1
            print(count2,i[1])
    elif(i[2][0]=='s'):
        best_pre = Find_Match_JaroWinkler(i[2],r_s)
        if(best_pre):
            count2+=1
            print(count2,i[1])
    elif(i[2][0]=='t'):
        best_pre = Find_Match_JaroWinkler(i[2],r_t)
        if(best_pre):
            count2+=1
            print(count2,i[1])
    elif(i[2][0]=='u'):
        best_pre = Find_Match_JaroWinkler(i[2],r_u)
        if(best_pre):
            count2+=1
            print(count2,i[1])
    elif(i[2][0]=='v'):
        best_pre = Find_Match_JaroWinkler(i[2],r_v)
        if(best_pre):
            count2+=1
            print(count2,i[1])
    elif(i[2][0]=='w'):
        best_pre = Find_Match_JaroWinkler(i[2],r_w)
        if(best_pre):
            count2+=1
            print(count2,i[1])
    elif(i[2][0]=='x'):
        best_pre = Find_Match_JaroWinkler(i[2],r_x)
        if(best_pre):
            count2+=1
            print(count2,i[1])
    elif(i[2][0]=='y'):
        best_pre = Find_Match_JaroWinkler(i[2],r_y)
        if(best_pre):
            count2+=1
            print(count2,i[1])
    elif(i[2][0]=='z'):
        best_pre = Find_Match_JaroWinkler(i[2],r_z)
        if(best_pre):
            count2+=1
            print(count2,i[1])
# Out:
# h h 1
# 1 aaah
# h h 1
# 2 aahh
# aroha arohpaida 0.9111111111111111
# 3 aahora
# hayila hayila 1
# 4 aaliyah
# etaivei etaivella 0.9047619047619048
# 5 abbrieviate
# cd cd 1
# 6 abdc
# g g 1
# 7 abeg
# o o 1
# 8 abeto
# otr otar 0.9166666666666666
# 9 abierto
# si si 1
# 10 abis
# nasi nasitra 0.9142857142857143
# 11 abisan
# ati atid 0.9166666666666666
# 12 abita
# mulb mulfeb 0.9222222222222222
# 13 ablum
# gni gnib 0.9166666666666666
# 14 aboarding
# noitanimno noitanimoba 0.9436363636363637
# 15 abonmination
# to to 1
# 16 abot
# sto stob 0.9166666666666666
# 17 abots
# u u 1
# 18 abou
# at at 1
# 19 abouta
# nt nt 1
# 20 aboutn
# ttuo tteuof 0.9111111111111111
# 21 aboutt
# at at 1
# 22 aboutta
# att atta 0.9166666666666666
# 23 abouttta
# ty ty 1
# 24 aboyt
# tup tuap 0.9166666666666666
# 25 abput
# e e 1
# 26 abreee
# l l 1
# 27 abril
# yletlu yletuca 0.9095238095238095
# 28 absoultely
# ylteulu yltneulf 0.9083333333333333
# 29 absouluetly
# aleu aleujac 0.9142857142857143
# ...

# %%
Result = open(r"C:\Users\JCCH4\Downloads\Result_of_Jaro_Winkler.txt")
line1 = 0
correct = 0
for i in Result:
    line1+=1
    if(line1%2==0):
        for k in blendwords1:
            if (i.split()[1]==k[0]):
                print(i.split()[1])
                correct+=1
print(correct,correct/10809)
# Out:
# amtrak
# bangel
# bash
# belieber
# bit
# blaxican
# bollywood
# bromance
# brunch
# californication
# cama
# camcorder
# cheeseburger
# chillax
# clash
# crackberry
# cranapple
# crooklyn
# daycation
# dentro
# dickhole
# dout
# dumpster
# ebonics
# escalator
# fantabulous
# femcee
# fooligan
# frappuccino
# fruitopia
# fugly
# ginormous
# gunk
# harmony
# henny
# herstory
# hijack
# hir
# homeboy
# hse
# hunty
# infomercial
# irregardless
# ital
# itouch
# jorts
# kendra
# limon
# macbook
# macon
# mahoosive
# malaysia
# manny
# mar
# medicaid
# melatonin
# meld
# merm
# metaverse
# metroplex
# microsoft
# minja
# modem
# motel
# motown
# mozilla
# naco
# neither
# nizzle
# nor
# overstand
# parkway
# payola
# planeteer
# pleather
# poofy
# popsicle
# prettiful
# prissy
# purrfect
# screamo
# sexpert
# sexting
# shag
# shamwow
# shero
# shim
# shwasted
# sial
# slithy
# slore
# smush
# snarf
# snark
# soca
# sony
# spanglish
# spunk
# stan
# steez
# sunlight
# telethon
# teme
# ...

# %%
for k in blendwords:
    print(k[0])
# Out:
# aaah
# aahh
# aahora
# aaliyah
# abangnya
# abbrieviate
# abdc
# abeg
# abegg
# abeto
# abi
# abierto
# abis
# abisan
# abita
# ablum
# aboarding
# abonmination
# abot
# abots
# abou
# abouta
# aboutn
# aboutt
# aboutta
# abouttt
# abouttta
# aboyt
# abput
# abreee
# abril
# absoultely
# absouluetly
# abtt
# abuela
# abuelo
# aca
# acaban
# acabar
# acabe
# acay
# accento
# accidenty
# accoutable
# accpect
# acee
# acepta
# aceptame
# acerques
# aceyy
# ackeem
# ackward
# acomplish
# acontecem
# acortan
# acquaintences
# acreditar
# acribiya
# actinq
# actitud
# activa
# activaa
# actlly
# actn
# actting
# actuaria
# acuerdate
# acuestase
# acustomed
# acutally
# adalah
# addicited
# addidas
# addin
# addressnya
# adedoying
# adek
# adesso
# adeyinka
# adhd
# adi
# adibas
# adidas
# adjc
# adjustin
# adlibs
# admirar
# admitt
# adolescente
# adopto
# adorablee
# adoro
# adroable
# adve
# advil
# advocators
# aed
# aent
# affraid
# afgan
# afghanastan
# africano
# africanoboishow
# ...

# %%
Find_Match_JaroWinkler("beefaroni",b)
# Out:
# beefaroni beearn 0.9222222222222222
# 'beearn'

# %%
r_r
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-ab6473e42df7> in <module>
# ----> 1 r_r
#
# NameError: name 'r_r' is not defined
